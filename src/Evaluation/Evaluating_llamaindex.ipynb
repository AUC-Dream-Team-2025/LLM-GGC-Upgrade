# %%
pip install datasets

# %%
pip install flash-attn

# %% [markdown]
# # Imports & Constants

# %%
from PIL import Image
import requests
import torch
from transformers import AutoProcessor, AutoModelForImageTextToText, Qwen2VLForConditionalGeneration
from datasets import load_dataset

# Constants for pixel constraints
max_pixels = 768 * 28 * 28
min_pixels = 1 * 28 * 28

# %% [markdown]
# # Load the Model and Processor

# %%
model = Qwen2VLForConditionalGeneration.from_pretrained(
    'llamaindex/vdr-2b-multi-v1',
    torch_dtype=torch.bfloat16,
    device_map="cuda:0"
).eval()

# Load the processor with pixel parameters
processor = AutoProcessor.from_pretrained(
    'llamaindex/vdr-2b-multi-v1',
    min_pixels=min_pixels,
    max_pixels=max_pixels
)

# Set padding side to left
model.padding_side = "left"
processor.tokenizer.padding_side = "left"

# %% [markdown]
# # Load the Dataset

# %%
# Load the dataset.
ds = load_dataset("hiyouga/geometry3k")
dataset = ds["train"]

# %%
dataset = ds["test"]
dataset
# Out:
# Dataset({
#     features: ['images', 'problem', 'answer', 'id', 'choices', 'ground_truth'],
#     num_rows: 601
# })

# %% [markdown]
# # Evaluation Function

# %%
def evaluate_model_on_dataset(model, processor, dataset, device="cuda:0", max_samples=None):
    """
    Evaluate the given model on the dataset.

    Each sample should have:
      - "images": the image to process,
      - "problem": the problem statement (dynamic prompt),
      - "ground_truth" or "answer": the expected output.

    Args:
      model: The image-text model to evaluate.
      processor: The processor associated with the model.
      dataset: A Hugging Face dataset.
      device: Device to run the evaluation on (default "cuda:0").
      max_samples: Optional integer limit to the number of samples to evaluate.

    Returns:
      A list of dictionaries with 'prediction', 'ground_truth', and 'problem' keys.
    """
    results = []

    for idx, sample in enumerate(dataset):
        if max_samples is not None and idx >= max_samples:
            break

        # Build the dynamic prompt using the sample's problem statement.
        prompt = (
            "<|im_start|>system\nYou are a helpful assistant.<|im_end|>\n"
            "<|im_start|>user\n" + sample["problem"] + "\n" +
            "<|vision_start|><|image_pad|><|vision_end|>" +
            "Please answer the above problem using the given image.<|im_end|>\n"
            "<|endoftext|>"
        )

        # Retrieve the image from the sample.
        image = sample["images"]

        # Get the ground truth from 'ground_truth', fallback to 'answer' if not available.
        ground_truth = sample.get("ground_truth", sample.get("answer", ""))

        # Process the inputs (both text prompt and image)
        inputs = processor(
            text=prompt,
            images=image,
            return_tensors="pt",
            padding="longest"
        ).to(device)

        # Directly generate output without calling prepare_inputs_for_generation.
        with torch.no_grad():
            output = model.generate(**inputs,max_new_tokens = 1)

        # Decode the result
        prediction = processor.decode(output[0], skip_special_tokens=True)

        results.append({
            "problem": sample["problem"],
            "prediction": prediction,
            "ground_truth": ground_truth
        })

        # Optional: Print progress every 10 samples
        if idx % 10 == 0:
            print(f"Processed sample {idx}")

    return results

# %% [markdown]
# # Run the Evaluation Function

# %%
# Evaluate the model on the dataset.
results = evaluate_model_on_dataset(model, processor, dataset, device="cuda:0", max_samples=None)

correct_predictions = 0
total_samples = len(results)
# Display the predictions along with their associated problem statement and ground truth.
for idx, item in enumerate(results):
    print(f"Sample {idx}:")
    print("Problem:", item["problem"])
    clean_prediction = item["prediction"][len(''' system
You are a helpful assistant.
user
 answer the above problem using the given image. ''')+len(item["problem"]):]

    print("Prediction:", clean_prediction)
    if(clean_prediction == item["ground_truth"]):
        correct_predictions += 1
    print("Ground Truth:", item["ground_truth"])
    print("-" * 50)
print("Accuricy:",correct_predictions/total_samples)
# Out:
# Processed sample 0
# Processed sample 10
# Processed sample 20
# Processed sample 30
# Processed sample 40
# Processed sample 50
# Processed sample 60
# Processed sample 70
# Processed sample 80
# Processed sample 90
# Processed sample 100
# Processed sample 110
# Processed sample 120
# Processed sample 130
# Processed sample 140
# Processed sample 150
# Processed sample 160
# Processed sample 170
# Processed sample 180
# Processed sample 190
# Processed sample 200
# Processed sample 210
# Processed sample 220
# Processed sample 230
# Processed sample 240
# Processed sample 250
# Processed sample 260
# Processed sample 270
# Processed sample 280
# Processed sample 290
# Processed sample 300
# Processed sample 310
# Processed sample 320
# Processed sample 330
# Processed sample 340
# Processed sample 350
# Processed sample 360
# Processed sample 370
# Processed sample 380
# Processed sample 390
# Processed sample 400
# Processed sample 410
# Processed sample 420
# Processed sample 430
# Processed sample 440
# Processed sample 450
# Processed sample 460
# Processed sample 470
# Processed sample 480
# Processed sample 490
# Processed sample 500
# Processed sample 510
# Processed sample 520
# Processed sample 530
# Processed sample 540
# Processed sample 550
# Processed sample 560
# Processed sample 570
# Processed sample 580
# Processed sample 590
# Processed sample 600
# Sample 0:
# Problem: In the figure, $\overline{A D}$ is perpendicular to $\overline{B C}$ and $\overline{A B}$ is perpendicular to $\overline{A C}$. What is $B C ?$
# Prediction: C
# Ground Truth: C
# --------------------------------------------------
# Sample 1:
# Problem: In $\odot M$, $FL=24,HJ=48$, and $m \widehat {HP}=65$. Find $m \widehat {PJ}$.
# Prediction: M
# Ground Truth: B
# --------------------------------------------------
# Sample 2:
# Problem: Find $G I$ if $G H=9, G K=6,$ and $K J=4$
# Prediction: G
# Ground Truth: D
# --------------------------------------------------
# Sample 3:
# Problem: in $\triangle XYZ$, $P$ is the centroid, $KP=3$, and $XJ=8$. Find $YJ$.
# Prediction: P
# Ground Truth: C
# --------------------------------------------------
# Sample 4:
# Problem: A regular pentagon and a square share a mutual vertex $X$. The sides $\overline{X Y}$ and $\overline{X Z}$ are sides of a third regular polygon with a vertex at $X .$ How many sides does this polygon have?
# Prediction: X
# Ground Truth: B
# --------------------------------------------------
# Sample 5:
# Problem: Use parallelogram $JKLM$ to find $m \angle KJL$.
# Prediction: R
# Ground Truth: A
# --------------------------------------------------
# Sample 6:
# Problem: Find x.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 7:
# Problem: Find x. Assume that segments that appear to be tangent are tangent.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 8:
# Problem: Find x to the nearest tenth. Assume that segments that appear to be tangent are tangent.
# Prediction: U
# Ground Truth: C
# --------------------------------------------------
# Sample 9:
# Problem: Find $m\angle CAM$
# Prediction: M
# Ground Truth: B
# --------------------------------------------------
# Sample 10:
# Problem: $a=14, b=48,$ and $c=50$ find $sinA$
# Prediction: in
# Ground Truth: B
# --------------------------------------------------
# Sample 11:
# Problem: Refer to the triangle shown below. Find $y$ to the nearest tenth.
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 12:
# Problem: In rhombus $A B C D, A B=2 x+3$ and $B C=5 x$. Find AD.
# Prediction: E
# Ground Truth: D
# --------------------------------------------------
# Sample 13:
# Problem: Find x
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 14:
# Problem: Find x.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 15:
# Problem: Find the measure of $\angle 3$.
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 16:
# Problem: Find $m \angle 1$ in the figure.
# Prediction: m
# Ground Truth: B
# --------------------------------------------------
# Sample 17:
# Problem: For trapezoid $Q R S T, A$ and $B$ are midpoints of the legs. Find $m \angle S$
# Prediction: Q
# Ground Truth: D
# --------------------------------------------------
# Sample 18:
# Problem: The diameters of $\odot A, \odot B,$ and $\odot C$ are 10, 30 and 10 units, respectively. Find AC if $\overline{A Z} \cong \overline{C W}$ and $C W=2$.
# Prediction: C
# Ground Truth: D
# --------------------------------------------------
# Sample 19:
# Problem: Find y. Round to the nearest tenth, if necessary.
# Prediction: y
# Ground Truth: C
# --------------------------------------------------
# Sample 20:
# Problem: Find the value of the variable $y$ in the figure.
# Prediction: 角度
# Ground Truth: B
# --------------------------------------------------
# Sample 21:
# Problem: In $\odot P$, the radius is $2$ inches, find the length of $\widehat {RS}$. Round to the nearest hundredth.
# Prediction: Q
# Ground Truth: C
# --------------------------------------------------
# Sample 22:
# Problem: Find x. Assume that segments that appear to be tangent are tangent. Round to the nearest tenth if necessary.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 23:
# Problem: Find $m \angle R C M$
# Prediction: M
# Ground Truth: B
# --------------------------------------------------
# Sample 24:
# Problem: Find the area of the figure. Round to the nearest tenth if necessary.
# Prediction: figure
# Ground Truth: B
# --------------------------------------------------
# Sample 25:
# Problem: Find $m \angle K$
# Prediction: K
# Ground Truth: C
# --------------------------------------------------
# Sample 26:
# Problem: Find $x$.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 27:
# Problem: Find $w$ in the given parallelogram
# Prediction: w
# Ground Truth: C
# --------------------------------------------------
# Sample 28:
# Problem: Find $KL$.
# Prediction: K
# Ground Truth: C
# --------------------------------------------------
# Sample 29:
# Problem: For trapezoid $ABCD$, $S$ and $T$ are midpoints of the legs. If $CD=14$, $ST=10$, and $AB=2x$, find $x$.
# Prediction: S
# Ground Truth: B
# --------------------------------------------------
# Sample 30:
# Problem: Find the height of the parallelogram given its area with 2000 square units.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 31:
# Problem: Find the area of the regular polygon figure. Round to the nearest tenth.
# Prediction: Oct
# Ground Truth: C
# --------------------------------------------------
# Sample 32:
# Problem: Find x. Round to the nearest tenth.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 33:
# Problem: Triangle $LMN$ is equilateral, and $\overline{MP}$ bisects $\overline{LN}$. Find $y$.
# Prediction: Triangle
# Ground Truth: D
# --------------------------------------------------
# Sample 34:
# Problem: If $\overline{PR} \| \overline{KL}, KN=9, LN=16,$ and $PM=2KP$, find $KM$.
# Prediction: Q
# Ground Truth: D
# --------------------------------------------------
# Sample 35:
# Problem: If WXYZ is a kite, find WP
# Prediction: W
# Ground Truth: A
# --------------------------------------------------
# Sample 36:
# Problem: Equilateral pentagon $P Q R S T$ is inscribed in $\odot U$.
# Find $m \angle P S R$
# Prediction: U
# Ground Truth: B
# --------------------------------------------------
# Sample 37:
# Problem: Find $AB$ if $\triangle ABC$ is an isosceles triangle with $\overline{AB} \cong \overline{BC}$.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 38:
# Problem: Use parallelogram PQRS to find $QP$
# Prediction:
# Ground Truth: B
# --------------------------------------------------
# Sample 39:
# Problem: Find the measure of $∠T$ to the nearest tenth.
# Prediction: S
# Ground Truth: A
# --------------------------------------------------
# Sample 40:
# Problem: $P$ is the incenter of $\triangle AEC$. Find $m \angle DEP$.
# Prediction: F
# Ground Truth: A
# --------------------------------------------------
# Sample 41:
# Problem: Find the circumference of the figure. Round to the nearest tenth.
# Prediction: figure
# Ground Truth: B
# --------------------------------------------------
# Sample 42:
# Problem: The diagonals of rhombus FGHJ intersect at K. If $GH = x + 9$ and $JH = 5x - 2$, find $x$.
# Prediction: F
# Ground Truth: A
# --------------------------------------------------
# Sample 43:
# Problem: Express the ratio of $\tan M$ as a decimal to the nearest hundredth.
# Prediction: M
# Ground Truth: B
# --------------------------------------------------
# Sample 44:
# Problem: $\overline{MN} \| \overline{BC}$. Solve for $x$.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 45:
# Problem: Find $x$.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 46:
# Problem: $\overline{HK}$ and $\overline{IG}$ are diameters of $\odot L$. Find $m \widehat {IHJ}$.
# Prediction: L
# Ground Truth: C
# --------------------------------------------------
# Sample 47:
# Problem: If $ST=8, TR=4$, and $PT=6$, find $QR$.
# Prediction: Q
# Ground Truth: C
# --------------------------------------------------
# Sample 48:
# Problem: Find x.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 49:
# Problem: Find $C F$ if $\overline{B F}$ bisects $\angle A B C$ and $\overline{A C} \| \overline{E D}, B A=6, B C=7.5$, $A C=9,$ and $D E=9$
# Prediction: C
# Ground Truth: C
# --------------------------------------------------
# Sample 50:
# Problem: Use parallelogram WXYZ to find $m\angle XYZ$
# Prediction: W
# Ground Truth: C
# --------------------------------------------------
# Sample 51:
# Problem: If RL = 5, RT = 9, and WS = 6, find RW.
# Prediction: L
# Ground Truth: D
# --------------------------------------------------
# Sample 52:
# Problem: Find the perimeter of $\triangle B C D,$ if $\triangle B C D \sim \triangle F D E, C D=12$, $F D=5, F E=4,$ and $D E=8$.
# Prediction: F
# Ground Truth: B
# --------------------------------------------------
# Sample 53:
# Problem: In $\odot X, A B=30, C D=30,$ and $m \widehat{C Z}=40$
# Find $m\widehat{C D}$
# Prediction: X
# Ground Truth: D
# --------------------------------------------------
# Sample 54:
# Problem: In $\odot X, A B=30, C D=30,$ and $m \widehat{C Z}=40$
# Find ND
# Prediction: X
# Ground Truth: B
# --------------------------------------------------
# Sample 55:
# Problem: Find $x$ for the equilateral triangle $RST$ if $RS = x + 9$, $ST = 2x$, and $RT = 3x - 9$.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 56:
# Problem: In the figure, $\triangle A B C \sim \triangle D E F . \overline{B G}$ is a median of $\triangle A B C,$ and $\overline{E H}$ is a median of $\triangle D E F .$ Find $E H$ if $B C=30, B G=15,$ and $E F=15$
# Prediction: triangles
# Ground Truth: A
# --------------------------------------------------
# Sample 57:
# Problem: Find the value of x.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 58:
# Problem: Find the measure of $\angle 7$ if $m∠4= m∠5$.
# Prediction:
# Ground Truth: D
# --------------------------------------------------
# Sample 59:
# Problem: Find $m \angle JKL$.
# Prediction: J
# Ground Truth: B
# --------------------------------------------------
# Sample 60:
# Problem: Find $x$.
# Prediction: X
# Ground Truth: D
# --------------------------------------------------
# Sample 61:
# Problem: $m \angle 2=2 x, m \angle 3=x$ Find $m\angle 3$
# Prediction: F
# Ground Truth: A
# --------------------------------------------------
# Sample 62:
# Problem: Find the value of the variable t.
# Prediction: t
# Ground Truth: C
# --------------------------------------------------
# Sample 63:
# Problem: Find $y$ so that each quadrilateral is a parallelogram.
# Prediction: Par
# Ground Truth: A
# --------------------------------------------------
# Sample 64:
# Problem: Find $m \angle ABC$.
# Prediction: BC
# Ground Truth: A
# --------------------------------------------------
# Sample 65:
# Problem: Use a Pythagorean Triple to find x.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 66:
# Problem: Find x.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 67:
# Problem: Find $m\angle W$
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 68:
# Problem: Find $m\angle A$
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 69:
# Problem: In $\odot O, \overline{E C}$ and $\overline{A B}$ are diameters, and $\angle B O D \cong \angle D O E \cong \angle E O F \cong \angle F O A$
# Find $m\widehat{A D}$
# Prediction: O
# Ground Truth: B
# --------------------------------------------------
# Sample 70:
# Problem: Circle $O$ has a radius of 13 inches. Radius $\overline{O B}$ is perpendicular to chord $\overline{C D}$ which is 24 inches long.
# Find OX
# Prediction: O
# Ground Truth: A
# --------------------------------------------------
# Sample 71:
# Problem: Find x. Round the angle measure to the nearest degree
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 72:
# Problem: Find the side length in isosceles triangle $DEF$.
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 73:
# Problem: Find BC
# Prediction: K
# Ground Truth: A
# --------------------------------------------------
# Sample 74:
# Problem: Express the ratio of $\cos N$ as a decimal to the nearest hundredth.
# Prediction: N
# Ground Truth: A
# --------------------------------------------------
# Sample 75:
# Problem: Find $y$ in each figure.
# Prediction: 角度
# Ground Truth: B
# --------------------------------------------------
# Sample 76:
# Problem: Find DE
# Prediction: BCDE
# Ground Truth: D
# --------------------------------------------------
# Sample 77:
# Problem: Find y
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 78:
# Problem: Find x.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 79:
# Problem: $MC=7,RM=4$, and $AT = 16$. Find $MB$.
# Prediction: R
# Ground Truth: B
# --------------------------------------------------
# Sample 80:
# Problem: Find $x$.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 81:
# Problem: In $\triangle DEF, m \angle E=108, m \angle F=26$, and $f=20$, Find $d$ to the nearest whole number.
# Prediction: f
# Ground Truth: B
# --------------------------------------------------
# Sample 82:
# Problem: If $XM=4,XN=6$, and $NZ=9$, find $XY$.
# Prediction: M
# Ground Truth: D
# --------------------------------------------------
# Sample 83:
# Problem: Find the length of $\widehat {AB}$. Round to the nearest hundredth.
# Prediction: O
# Ground Truth: B
# --------------------------------------------------
# Sample 84:
# Problem: Find x. Assume that segments that appear to be tangent are tangent.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 85:
# Problem: Use parallelogram ABCD to find $m\angle ACD$
# Prediction: F
# Ground Truth: B
# --------------------------------------------------
# Sample 86:
# Problem: Find $\angle C$ of quadrilateral ABCD
# Prediction: quadr
# Ground Truth: B
# --------------------------------------------------
# Sample 87:
# Problem: Find $x$.
# Prediction: Triangle
# Ground Truth: A
# --------------------------------------------------
# Sample 88:
# Problem: Find x.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 89:
# Problem: In the figure, $m∠1 = 50$ and $m∠3 = 60$. Find the measure of $\angle 4$.
# Prediction: q
# Ground Truth: B
# --------------------------------------------------
# Sample 90:
# Problem: Tangent $\overline{M P}$ is drawn to $\odot O .$ Find $x$ if $M O=20$
# Prediction: M
# Ground Truth: C
# --------------------------------------------------
# Sample 91:
# Problem: Find x. Round to the nearest hundredth.
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 92:
# Problem: $∠6$ and $∠8$ are complementary, $m∠8 = 47$. Find the measure of $\angle 7$.
# Prediction:
# Ground Truth: D
# --------------------------------------------------
# Sample 93:
# Problem: Find AB
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 94:
# Problem: Find $x$.
# Prediction:
# Ground Truth: B
# --------------------------------------------------
# Sample 95:
# Problem: Find x so that $GJ \parallel FK$. $G H=x+3.5, H J=x-8.5, F H=21, H K=7$.
#
# Prediction: G
# Ground Truth: C
# --------------------------------------------------
# Sample 96:
# Problem: Find the area of the trapezoid.
# Prediction: 积
# Ground Truth: C
# --------------------------------------------------
# Sample 97:
# Problem: $m \angle BAC=38$, $BC=5$, and $DC=5$, find $m \angle DAC$.
# Prediction: C
# Ground Truth: C
# --------------------------------------------------
# Sample 98:
# Problem: Find the measure of the altitude drawn to the hypotenuse.
# Prediction: 角
# Ground Truth: C
# --------------------------------------------------
# Sample 99:
# Problem: Each pair of polygons is similar. Find AC
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 100:
# Problem: The area $A$ of the shaded region is given. Find $x$. $A = 66$ cm$^2$ .
# Prediction: A
# Ground Truth: C
# --------------------------------------------------
# Sample 101:
# Problem: Find the area of the parallelogram. Round to the nearest tenth if necessary.
# Prediction: Square
# Ground Truth: C
# --------------------------------------------------
# Sample 102:
# Problem: Find the area of the shaded region. Assume that the polygon is regular unless otherwise stated. Round to the nearest tenth.
# Prediction: 角
# Ground Truth: A
# --------------------------------------------------
# Sample 103:
# Problem: Find the value of the variable $x$ in the figure.
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 104:
# Problem: Find x
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 105:
# Problem: Find $m \angle H$.
# Prediction: K
# Ground Truth: B
# --------------------------------------------------
# Sample 106:
# Problem: Find $x$ if $\triangle JLM \sim \triangle QST$.
# Prediction: Q
# Ground Truth: A
# --------------------------------------------------
# Sample 107:
# Problem: Find $h$ in each triangle.
# Prediction: h
# Ground Truth: A
# --------------------------------------------------
# Sample 108:
# Problem: Find $m\angle MPQ$.
# Prediction: M
# Ground Truth: D
# --------------------------------------------------
# Sample 109:
# Problem: Find PT
# Prediction: PT
# Ground Truth: B
# --------------------------------------------------
# Sample 110:
# Problem: If DB = 24, AE = 3, and EC = 18, find AD
# Prediction: E
# Ground Truth: B
# --------------------------------------------------
# Sample 111:
# Problem: Find the area of the figure. Round to the nearest tenth if necessary.
# Prediction: 角
# Ground Truth: A
# --------------------------------------------------
# Sample 112:
# Problem: Use parallelogram $JKLM$ to find $m \angle JKL$.
# Prediction: R
# Ground Truth: C
# --------------------------------------------------
# Sample 113:
# Problem: Find y.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 114:
# Problem: Express the ratio of $\cos A$ as a decimal to the nearest hundredth.
# Prediction: A
# Ground Truth: A
# --------------------------------------------------
# Sample 115:
# Problem: $\overline{WTY} \cong \overline{TWY}$. Find $x$.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 116:
# Problem: JKLM is a rectangle. MLPR is a rhombus. $\angle J M K \cong \angle R M P$, $m \angle J M K=55, \text { and } m \angle M R P=70 . Find $m \angle K L P$
# Prediction: JL
# Ground Truth: D
# --------------------------------------------------
# Sample 117:
# Problem: $\triangle BCD \cong \triangle WXY$. Find $x$.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 118:
# Problem: Find the area of the parallelogram.
# Prediction: paralle
# Ground Truth: A
# --------------------------------------------------
# Sample 119:
# Problem: Find $m \angle ABC$.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 120:
# Problem: Find x. Round to the nearest tenth.
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 121:
# Problem: Find y
# Prediction: y
# Ground Truth: A
# --------------------------------------------------
# Sample 122:
# Problem: Use parallelogram ABCD to find $m \angle CDF $
# Prediction: F
# Ground Truth: B
# --------------------------------------------------
# Sample 123:
# Problem: Quadrilateral $ABDC$ is a rectangle. If $m\angle1 = 38$, find $m \angle 2$
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 124:
# Problem: Find x
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 125:
# Problem: Use parallelogram MNPR to find $m \angle MNP$
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 126:
# Problem: Express the ratio of $\cos P$ as a decimal to the nearest hundredth.
# Prediction: Q
# Ground Truth: A
# --------------------------------------------------
# Sample 127:
# Problem: Find $x$.
# Prediction: K
# Ground Truth: D
# --------------------------------------------------
# Sample 128:
# Problem: If $AB=12,AC=16$, and $ED=5$, find $AE$.
# Prediction: triangles
# Ground Truth: C
# --------------------------------------------------
# Sample 129:
# Problem: In $\odot F, \overline{F H} \cong \overline{F L}$ and $\mathrm{FK}=17$.
# Find JG
# Prediction: F
# Ground Truth: D
# --------------------------------------------------
# Sample 130:
# Problem: Find z
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 131:
# Problem: Find $x$ so that the quadrilateral is a parallelogram.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 132:
# Problem: Find the perimeter of the parallelogram. Round to the nearest tenth if necessary.
# Prediction: cm
# Ground Truth: B
# --------------------------------------------------
# Sample 133:
# Problem: Find x
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 134:
# Problem: In the figure, $m∠1 = 50$ and $m∠3 = 60$. Find the measure of $\angle 6$.
# Prediction: q
# Ground Truth: C
# --------------------------------------------------
# Sample 135:
# Problem: Find $\widehat{\mathrm{WN}}$ if $\triangle \mathrm{IWN}$ is equilateral and $W N=5$
# Prediction: WN
# Ground Truth: B
# --------------------------------------------------
# Sample 136:
# Problem: Express the ratio of $\sin N$ as a decimal to the nearest hundredth.
# Prediction: N
# Ground Truth: C
# --------------------------------------------------
# Sample 137:
# Problem: If $A E=m-2, E C=m+4$， $A D=4,$ and $A B=20,$ find $m$
# Prediction: m
# Ground Truth: B
# --------------------------------------------------
# Sample 138:
# Problem: If $CE=t-2$. $EB=t+1$, $CD=2$, and $CA=10$, find $CE$.
# Prediction: triangles
# Ground Truth: A
# --------------------------------------------------
# Sample 139:
# Problem: Use parallelogram ABCD to find $m \angle AFD $
# Prediction: F
# Ground Truth: D
# --------------------------------------------------
# Sample 140:
# Problem: In the figure, line $l$ is parallel to line $m$. Line $n$ intersects both $l$ and $m$. Which of the following lists includes all of the angles that are supplementary to $ ∠1 $?
# Prediction: n
# Ground Truth: A
# --------------------------------------------------
# Sample 141:
# Problem: Find the perimeter of the parallelogram. Round to the nearest tenth if necessary.
# Prediction: par
# Ground Truth: D
# --------------------------------------------------
# Sample 142:
# Problem: Find x. Round to the nearest tenth.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 143:
# Problem: Find x.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 144:
# Problem: Circles $G, J,$ and $K$ all intersect at $L$ If $G H=10$, find FH
# Prediction: L
# Ground Truth: C
# --------------------------------------------------
# Sample 145:
# Problem: Find $CD$ if $AC=x-3$, $BE=20, AB=16,$ and $CD=x+5$
# Prediction: D
# Ground Truth: D
# --------------------------------------------------
# Sample 146:
# Problem: Find $m \angle 4$.
# Prediction: U
# Ground Truth: C
# --------------------------------------------------
# Sample 147:
# Problem: Find the area of the triangle. Round to the nearest tenth if necessary.
# Prediction: triangle
# Ground Truth: C
# --------------------------------------------------
# Sample 148:
# Problem: In regular hexagon UVWXYZ, each side is 12 centimeters long. Find $W Y$.
# Prediction: hex
# Ground Truth: C
# --------------------------------------------------
# Sample 149:
# Problem: For the pair of similar figures, use the given areas to find the scale factor from the blue to the green figure.
# Prediction: blue
# Ground Truth: B
# --------------------------------------------------
# Sample 150:
# Problem: Find x. Assume that segments that appear to be tangent are tangent.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 151:
# Problem: What is the measure of $\angle B$ if $m \angle A=10 ?$
# Prediction: A
# Ground Truth: A
# --------------------------------------------------
# Sample 152:
# Problem: Find y.
# Prediction: y
# Ground Truth: B
# --------------------------------------------------
# Sample 153:
# Problem: In the figure, $m∠3 = 110$ and $m ∠ 12 = 55$. Find the measure of $∠13$.
# Prediction: m
# Ground Truth: A
# --------------------------------------------------
# Sample 154:
# Problem: Express the ratio of $\tan L$ as a decimal to the nearest hundredth.
# Prediction: L
# Ground Truth: B
# --------------------------------------------------
# Sample 155:
# Problem: In $\odot O, \overline{E C}$ and $\overline{A B}$ are diameters, and $\angle B O D \cong \angle D O E \cong \angle E O F \cong \angle F O A$
# Find $m\widehat{A E}$
# Prediction: O
# Ground Truth: B
# --------------------------------------------------
# Sample 156:
# Problem: Find y
# Prediction: y
# Ground Truth: C
# --------------------------------------------------
# Sample 157:
# Problem: Find $a,$ if $F G=18, G H=42,$ and $F K=15$
# Prediction: F
# Ground Truth: D
# --------------------------------------------------
# Sample 158:
# Problem: Point $D$ is the center of the circle. What is $m \angle A B C ?$
# Prediction: D
# Ground Truth: D
# --------------------------------------------------
# Sample 159:
# Problem: Find the value of the variable $x$ in the figure.
# Prediction: figure
# Ground Truth: B
# --------------------------------------------------
# Sample 160:
# Problem: Given that the perimeter of $\triangle A B C=25,$ find $x$. Assume that segments that appear tangent to circles are tangent.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 161:
# Problem: In the figure, $m∠1 = 50$ and $m∠3 = 60$. Find the measure of $\angle 8$.
# Prediction: q
# Ground Truth: C
# --------------------------------------------------
# Sample 162:
# Problem: Use parallelogram ABCD to find $m\angle DAC$
# Prediction: F
# Ground Truth: C
# --------------------------------------------------
# Sample 163:
# Problem: The degree measures of minor arc $\widehat{A C}$ and major arc $\widehat{A D C}$ are $x$ and $y$ respectively. If $m∠ABC = 70°$, find $x$.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 164:
# Problem: Find $m \angle A B C$
# if $m \angle C D A=61$
# Prediction: m
# Ground Truth: D
# --------------------------------------------------
# Sample 165:
# Problem: Circle $J$ has a radius of $10$ units, $\odot K$ has a radius of $8$ units, and $BC=5.4$ units. Find $JK$.
# Prediction: circles
# Ground Truth: A
# --------------------------------------------------
# Sample 166:
# Problem: If $c=5,$ find $a$
# Prediction: c
# Ground Truth: A
# --------------------------------------------------
# Sample 167:
# Problem: What is the value of $x$ below to the nearest tenth?
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 168:
# Problem: Find the area of the shaded region.
# Prediction: shaded
# Ground Truth: C
# --------------------------------------------------
# Sample 169:
# Problem: $\overrightarrow{QP}$ and $\overrightarrow{QR}$ are opposite rays, and $\overrightarrow{QT}$ bisects $\angle SOR$. If $m \angle SOR=6x+8$ and $m \angle TOR=4x-14,$ find $m \angle SQT$.
# Prediction: P
# Ground Truth: D
# --------------------------------------------------
# Sample 170:
# Problem: $UJ=9, VJ=3$, and $ZT=18$. Find $SJ$.
# Prediction: U
# Ground Truth: B
# --------------------------------------------------
# Sample 171:
# Problem: Cut four congruent triangles off the corners of a rectangle to make an octagon. What is the area of the octagon?
# Prediction: oct
# Ground Truth: B
# --------------------------------------------------
# Sample 172:
# Problem: Use a calculator to find the measure of $∠J$ to the nearest degree.
# Prediction: L
# Ground Truth: B
# --------------------------------------------------
# Sample 173:
# Problem: Quadrilateral EFGH is a rectangle. If $m \angle HGE = 13$, find $m\angle FGE$.
# Prediction: K
# Ground Truth: D
# --------------------------------------------------
# Sample 174:
# Problem: $ABCD$ is a rhombus. If $PB = 12$, $AB = 15$, and $m \angle ABD = 24$, Find $m\angle BDA$
# Prediction: AB
# Ground Truth: A
# --------------------------------------------------
# Sample 175:
# Problem: Find z
# Prediction: Z
# Ground Truth: C
# --------------------------------------------------
# Sample 176:
# Problem: Find the measure of $\angle 3$ if $\overline{A B} \perp \overline{B C}$.
# Prediction:
# Ground Truth: D
# --------------------------------------------------
# Sample 177:
# Problem: Find $m\angle B$
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 178:
# Problem: Find the measure of $∠A$ to the nearest tenth.
# Prediction: A
# Ground Truth: B
# --------------------------------------------------
# Sample 179:
# Problem: A square is inscribed in a circle of area 18$\pi$ square units. Find the length of a side of the square.
# Prediction: square
# Ground Truth: C
# --------------------------------------------------
# Sample 180:
# Problem: $\overline{AB}$ is a diameter, $AC=8$ inches, and $BC=15$ inches. Find the radius of the circle.
# Prediction: AB
# Ground Truth: C
# --------------------------------------------------
# Sample 181:
# Problem: Find $m \angle 1$.
# Prediction: m
# Ground Truth: B
# --------------------------------------------------
# Sample 182:
# Problem: Find $x$.
# Prediction:
# Ground Truth: A
# --------------------------------------------------
# Sample 183:
# Problem:  In RSTV, RS $=6, V T=3$ and $R X$ is twice the length of $X V .$ Find $X Y .$
# Prediction: R
# Ground Truth: B
# --------------------------------------------------
# Sample 184:
# Problem: Find the area of the regular polygon figure. Round to the nearest tenth.
# Prediction: Regular
# Ground Truth: C
# --------------------------------------------------
# Sample 185:
# Problem: $\overline{GJ}$ is a diameter of $\odot K$. Find $m \widehat {GLJ}$.
# Prediction: K
# Ground Truth: C
# --------------------------------------------------
# Sample 186:
# Problem: Find $m\angle V X W$
# Prediction: V
# Ground Truth: B
# --------------------------------------------------
# Sample 187:
# Problem: In the figure, $\overline{CP}$ is an altitude, $\overline{CQ}$ is the angle bisector of $∠ACB$, and $R$ is the midpoint of $\overline{AB}$. Find  $m∠ACQ$ if $m∠ACB=123-x$ and $m∠QCB = 42 + x$.
# Prediction: R
# Ground Truth: D
# --------------------------------------------------
# Sample 188:
# Problem: Find $m \angle 2$ if $m \widehat{B C}=30$ and $m \widehat{A D}=20$
# Prediction: m
# Ground Truth: D
# --------------------------------------------------
# Sample 189:
# Problem: Find the area of the parallelogram. Round to the nearest tenth if necessary.
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 190:
# Problem: Quadrilateral DEFG is a rectangle. If $m\angle EDF = 5x - 3$ and $m\angle DFG = 3x + 7$, find $m\angle EDF$.
# Prediction: quadr
# Ground Truth: A
# --------------------------------------------------
# Sample 191:
# Problem: Express the ratio of $\sin P$ as a decimal to the nearest hundredth.
# Prediction: Q
# Ground Truth: C
# --------------------------------------------------
# Sample 192:
# Problem: Find x. Round to the nearest tenth, if necessary.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 193:
# Problem: Find x. Assume that segments that appear to be tangent are tangent.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 194:
# Problem: Find $XY$ of isosceles $\triangle XYZ$
# Prediction: triangles
# Ground Truth: B
# --------------------------------------------------
# Sample 195:
# Problem: Find x. Round to the nearest tenth.
#
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 196:
# Problem: Find the perimeter of the figure. Round to the nearest tenth if necessary.
# Prediction: figure
# Ground Truth: C
# --------------------------------------------------
# Sample 197:
# Problem: Find the measure of $∠Z$ to the nearest tenth.
# Prediction:
# Ground Truth: B
# --------------------------------------------------
# Sample 198:
# Problem: Find $x$.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 199:
# Problem: Find $m \angle Y$
# Prediction: Y
# Ground Truth: A
# --------------------------------------------------
# Sample 200:
# Problem: In H, the diameter is $18$, $LM = 12$, and $m \widehat {LM} = 84$. Find $HP$. Round to the nearest hundredth.
# Prediction: H
# Ground Truth: D
# --------------------------------------------------
# Sample 201:
# Problem: Find x to the nearest tenth. Assume that segments that appear to be tangent are tangent.
# Prediction: X
# Ground Truth: A
# --------------------------------------------------
# Sample 202:
# Problem: Find $XW$.
# Prediction: X
# Ground Truth: B
# --------------------------------------------------
# Sample 203:
# Problem: Find $QM$.
# Prediction: Q
# Ground Truth: C
# --------------------------------------------------
# Sample 204:
# Problem: Find $x$ so that $m || n$.
# Prediction: m
# Ground Truth: B
# --------------------------------------------------
# Sample 205:
# Problem: Find the value of $x$
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 206:
# Problem: $m \angle 4=2 y+32$ and $m \angle 5=3 y-3$. Find $y$.
# Prediction:
# Ground Truth: B
# --------------------------------------------------
# Sample 207:
# Problem: Refer to the figure at the right. Find x.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 208:
# Problem: Find the measure of $m \widehat{YXZ}$.
# Prediction: V
# Ground Truth: B
# --------------------------------------------------
# Sample 209:
# Problem: Find the area of the shaded region. Round to the nearest tenth.
# Prediction: 五
# Ground Truth: B
# --------------------------------------------------
# Sample 210:
# Problem: Find the area of the figure.
# Prediction: 角
# Ground Truth: B
# --------------------------------------------------
# Sample 211:
# Problem: In $\triangle CDF$, $K$ is the centroid and $DK=16$. Find $CD$.
# Prediction: K
# Ground Truth: C
# --------------------------------------------------
# Sample 212:
# Problem: Find $m \angle R$
# Prediction: Q
# Ground Truth: A
# --------------------------------------------------
# Sample 213:
# Problem: In the figure, $m ∠ 12 = 64$. Find the measure of $ \angle 7$.
# Prediction: w
# Ground Truth: B
# --------------------------------------------------
# Sample 214:
# Problem: Find the area of the parallelogram. Round to the nearest tenth if necessary.
# Prediction: paralle
# Ground Truth: C
# --------------------------------------------------
# Sample 215:
# Problem: Find the perimeter of the parallelogram. Round to the nearest tenth if necessary.
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 216:
# Problem: Find $m \angle CAD$.
# Prediction: A
# Ground Truth: B
# --------------------------------------------------
# Sample 217:
# Problem: Find $m \angle 3$.
# Prediction:
# Ground Truth: B
# --------------------------------------------------
# Sample 218:
# Problem: $\overline{AD}$ and $\overline{CG}$ are diameters of $\odot B$. Find $m \widehat {AG}$.
# Prediction:
# Ground Truth: D
# --------------------------------------------------
# Sample 219:
# Problem: Find $ST$.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 220:
# Problem: Find $TQ$.
# Prediction: Q
# Ground Truth: C
# --------------------------------------------------
# Sample 221:
# Problem: Find $m \widehat {JKL}$.
# Prediction: L
# Ground Truth: C
# --------------------------------------------------
# Sample 222:
# Problem: In the figure, a regular polygon is inscribed in a circle. Find the measure of a central angle.
# Prediction: entral
# Ground Truth: B
# --------------------------------------------------
# Sample 223:
# Problem: parallelogram MNPQ with $m \angle M=10 x$ and $m \angle N=20 x$, find $\angle M$
# Prediction: M
# Ground Truth: C
# --------------------------------------------------
# Sample 224:
# Problem: Find $m \angle B$.
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 225:
# Problem: $m \angle 3=x-12$ and $m \angle 6=72$. Find $x$.
# Prediction:
# Ground Truth: D
# --------------------------------------------------
# Sample 226:
# Problem: Find x. Round to the nearest tenth if necessary. Assume that segments that appear
# to be tangent are tangent.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 227:
# Problem: ABCD is a parallelogram with side lengths as indicated in the figure at the right. The perimeter of ABCD is 22. Find AB
# Prediction: w
# Ground Truth: A
# --------------------------------------------------
# Sample 228:
# Problem: Find z.
# Prediction: z
# Ground Truth: C
# --------------------------------------------------
# Sample 229:
# Problem: Quadrilateral $WXYZ$ is a rectangle. Find the measure of $\angle 3$ if $m∠1 = 30$.
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 230:
# Problem: A plane travels from Des Moines to Phoenix, on to Atlanta, and back to Des Moines, as shown below. Find the distance in miles from  Phoenix to Atlanta if the total trip was 3482 miles.
# Prediction: triangles
# Ground Truth: D
# --------------------------------------------------
# Sample 231:
# Problem: Find $x$.
# Prediction: X
# Ground Truth: C
# --------------------------------------------------
# Sample 232:
# Problem: Find x.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 233:
# Problem: Find x.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 234:
# Problem: Find x
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 235:
# Problem: Find the area of the shaded region formed by the circle and regular polygon. Round to the nearest tenth.
# Prediction: Pentagon
# Ground Truth: A
# --------------------------------------------------
# Sample 236:
# Problem: Find the area of the triangle.
# Prediction: 角
# Ground Truth: B
# --------------------------------------------------
# Sample 237:
# Problem: In the figure, $m \angle 1=4 p+15$, $m \angle 3=3 p-10$ and $m \angle 4=6 r+5 $. Find the value of $p$.
# Prediction: p
# Ground Truth: C
# --------------------------------------------------
# Sample 238:
# Problem: Find $x$
# Prediction: X
# Ground Truth: A
# --------------------------------------------------
# Sample 239:
# Problem: The diagram shows the layout of Elm, Plum, and Oak streets. Find the value of $x.$
# Prediction: Elm
# Ground Truth: C
# --------------------------------------------------
# Sample 240:
# Problem: Find $m \angle N C L$
# Prediction: M
# Ground Truth: B
# --------------------------------------------------
# Sample 241:
# Problem: Find y
# Prediction: y
# Ground Truth: D
# --------------------------------------------------
# Sample 242:
# Problem: Each pair of polygons is similar. Find GF
# Prediction: R
# Ground Truth: A
# --------------------------------------------------
# Sample 243:
# Problem: Find x in the figure.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 244:
# Problem: Find $m \angle 6$
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 245:
# Problem: Find TX if $E X=24$ and $D E=7$
# Prediction: Q
# Ground Truth: D
# --------------------------------------------------
# Sample 246:
# Problem: Find x.
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 247:
# Problem: Find the measure of $m\angle 2$. Assume that segments that appear
# tangent are tangent.
# Prediction:
# Ground Truth: B
# --------------------------------------------------
# Sample 248:
# Problem: Find x in the parallelogram
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 249:
# Problem: If $A B C D$ is a rhombus, and $m \angle A B C=70^{\circ}$, what is $m \angle 1 ?$
# Prediction: rh
# Ground Truth: B
# --------------------------------------------------
# Sample 250:
# Problem: Find the area of the figure. Round to the nearest tenth if necessary.
# Prediction: figure
# Ground Truth: C
# --------------------------------------------------
# Sample 251:
# Problem: Find x
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 252:
# Problem: Find the area of the figure.
# Prediction: rectangle
# Ground Truth: D
# --------------------------------------------------
# Sample 253:
# Problem: $P Q R S$ is a rhombus inscribed in a circle. Find $m \widehat{SP}$
# Prediction: Q
# Ground Truth: D
# --------------------------------------------------
# Sample 254:
# Problem: Find GH in the kite
# Prediction: F
# Ground Truth: D
# --------------------------------------------------
# Sample 255:
# Problem: Find $QP$.
# Prediction: Q
# Ground Truth: B
# --------------------------------------------------
# Sample 256:
# Problem: Find x
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 257:
# Problem: Lines $l$, $m$, and $n$ are perpendicular bisectors of $\triangle PQR$ and meet at $T$. If $TQ = 2x$, $PT = 3y - 1$, and $TR = 8$, find $z$.
# Prediction: n
# Ground Truth: A
# --------------------------------------------------
# Sample 258:
# Problem: Find the value of x.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 259:
# Problem: In $\odot T, Z V=1,$ and $T W=13$. Find XY
# Prediction: T
# Ground Truth: B
# --------------------------------------------------
# Sample 260:
# Problem: Find $x$.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 261:
# Problem: In $\odot S$, $m \widehat {PQR}=98$, Find $m \widehat {PQ}$.
# Prediction: T
# Ground Truth: B
# --------------------------------------------------
# Sample 262:
# Problem: Find the area of the parallelogram. Round to the nearest tenth if necessary.
# Prediction: paralle
# Ground Truth: B
# --------------------------------------------------
# Sample 263:
# Problem: Find y
# Prediction: y
# Ground Truth: C
# --------------------------------------------------
# Sample 264:
# Problem: Find the area of the figure. Round to the nearest tenth if necessary.
# Prediction: figure
# Ground Truth: C
# --------------------------------------------------
# Sample 265:
# Problem: Find $GD$.
# Prediction: H
# Ground Truth: C
# --------------------------------------------------
# Sample 266:
# Problem: Find $m\angle W$
# Prediction: U
# Ground Truth: C
# --------------------------------------------------
# Sample 267:
# Problem: Find the scale from $B$ to $B'$.
# Prediction: Q
# Ground Truth: D
# --------------------------------------------------
# Sample 268:
# Problem: Find $z$.
# Prediction: z
# Ground Truth: C
# --------------------------------------------------
# Sample 269:
# Problem: Find the area of the parallelogram.
# Prediction: ar
# Ground Truth: B
# --------------------------------------------------
# Sample 270:
# Problem: Find x.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 271:
# Problem: Find the area of the figure. Round to the nearest tenth if necessary.
# Prediction: km
# Ground Truth: C
# --------------------------------------------------
# Sample 272:
# Problem: Find the area of the parallelogram. Round to the nearest tenth if necessary.
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 273:
# Problem: Find x.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 274:
# Problem: For trapezoid $T R S V, M$ and $N$ are midpoints of the legs. If $T R=32$ and $M N=25,$ find $V S$
# Prediction: M
# Ground Truth: A
# --------------------------------------------------
# Sample 275:
# Problem: In $\odot P, m \angle M P L=65$ and $\overline{N P} \perp \overline{P L}$.
# Find $m \widehat{N J K}$
# Prediction: m
# Ground Truth: D
# --------------------------------------------------
# Sample 276:
# Problem: Find y.
# Prediction: y
# Ground Truth: B
# --------------------------------------------------
# Sample 277:
# Problem: $\overline{CH} \cong \overline{KJ}$. Find $x$.
# Prediction: L
# Ground Truth: C
# --------------------------------------------------
# Sample 278:
# Problem: Find the measure of $\angle 3$ if $m∠4= m∠5$.
# Prediction:
# Ground Truth: A
# --------------------------------------------------
# Sample 279:
# Problem: Find $WR$.
# Prediction: T
# Ground Truth: B
# --------------------------------------------------
# Sample 280:
# Problem: In $\triangle PQR$, $ZQ=3a-11$, $ZP=a+5$, $PY=2 c-1$, $YR=4 c-11$, $m \angle PRZ=4 b-17$, $m \angle ZRQ=3 b-4$, $m \angle QYR=7 b+6$, and $m \angle PXR=2 a+10$.  If $\overline{RZ}$ is an angle bisector, find $m∠PRZ$.
# Prediction: angles
# Ground Truth: D
# --------------------------------------------------
# Sample 281:
# Problem: Find y.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 282:
# Problem: Find $x$.
# Prediction:
# Ground Truth: B
# --------------------------------------------------
# Sample 283:
# Problem: Find $EG$ if $G$ is the incenter of $\triangle ABC$.
# Prediction: G
# Ground Truth: B
# --------------------------------------------------
# Sample 284:
# Problem: Find $x$ in the figure.
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 285:
# Problem: Find x.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 286:
# Problem: One diagonal of a rhombus is twice as long as the other diagonal. If the area of the rhombus is 169 square millimeters, what are the lengths of the diagonals?
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 287:
# Problem: Use parallelogram ABCD to find $m\angle ADC$
# Prediction: F
# Ground Truth: D
# --------------------------------------------------
# Sample 288:
# Problem: Find $x$.
# Prediction: U
# Ground Truth: B
# --------------------------------------------------
# Sample 289:
# Problem: Use parallelogram to find $b$
# Prediction: b
# Ground Truth: B
# --------------------------------------------------
# Sample 290:
# Problem: Find $y$ so that the quadrilateral is a parallelogram
# Prediction: quadr
# Ground Truth: B
# --------------------------------------------------
# Sample 291:
# Problem: Find $m \angle 1$.
# Prediction: X
# Ground Truth: A
# --------------------------------------------------
# Sample 292:
# Problem: What is the area of $▱ ABCD$?
# Prediction: ABC
# Ground Truth: C
# --------------------------------------------------
# Sample 293:
# Problem: Find the scale factor from $W$ to $W'$.
# Prediction: W
# Ground Truth: A
# --------------------------------------------------
# Sample 294:
# Problem: Circles $G, J,$ and $K$ all intersect at $L$ If $G H=10,$ find each measure.
# Find JL
# Prediction: G
# Ground Truth: A
# --------------------------------------------------
# Sample 295:
# Problem: If $m∠5 = 7x - 5$ and $m∠4 = 2x + 23$, find $x$.
# Prediction: m
# Ground Truth: B
# --------------------------------------------------
# Sample 296:
# Problem: Find $PN$.
# Prediction: L
# Ground Truth: B
# --------------------------------------------------
# Sample 297:
# Problem: Find x. Assume that any segment that appears to be tangent is tangent.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 298:
# Problem: Find the length of $\widehat {JK}$. Round to the nearest hundredth.
# Prediction: C
# Ground Truth: B
# --------------------------------------------------
# ...
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 503:
# Problem: If $LK=4,MP=3,PQ=6,KJ=2,RS=6$, and $LP=2$, find $JH$.
# Prediction: triangles
# Ground Truth: C
# --------------------------------------------------
# Sample 504:
# Problem: Find $x$.
# Prediction: L
# Ground Truth: D
# --------------------------------------------------
# Sample 505:
# Problem: Find $h$ in the triangle.
# Prediction: h
# Ground Truth: D
# --------------------------------------------------
# Sample 506:
# Problem: $m \angle 2=2 x, m \angle 3=x$ Find $m\angle 2$
# Prediction: F
# Ground Truth: C
# --------------------------------------------------
# Sample 507:
# Problem: Find $m∠1$.
# Prediction: m
# Ground Truth: C
# --------------------------------------------------
# Sample 508:
# Problem: $\overline{AB}$ is a diameter, $AC=8$ inches, and $BC=15$ inches. Find the circumference of the circle.
# Prediction:
# Ground Truth: D
# --------------------------------------------------
# Sample 509:
# Problem: Find the measure of $\angle 2$.
# Prediction:
# Ground Truth: B
# --------------------------------------------------
# Sample 510:
# Problem: Find $m \angle RST$.
# Prediction: R
# Ground Truth: A
# --------------------------------------------------
# Sample 511:
# Problem: A square is inscribed in a circle having a radius of $6$ inches. Find the length of each side of the square.
# Prediction: circle
# Ground Truth: C
# --------------------------------------------------
# Sample 512:
# Problem: Find $x$.
# Prediction:
# Ground Truth: A
# --------------------------------------------------
# Sample 513:
# Problem: Refer to the figure at the right. Find y.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 514:
# Problem: In rhombus $A B C D, m \angle D A B=2, m \angle A D C$ and $C B=6$. Find $m \angle A D B$
# Prediction:
# Ground Truth: A
# --------------------------------------------------
# Sample 515:
# Problem: Triangle $LMN$ is equilateral, and $\overline{MP}$ bisects $\overline{LN}$. Find the measure of each side of $\triangle LMN$.
# Prediction: Triangle
# Ground Truth: B
# --------------------------------------------------
# Sample 516:
# Problem: Find $x$.
# Prediction: triangles
# Ground Truth: B
# --------------------------------------------------
# Sample 517:
# Problem: Find $x$ in the given parallelogram
# Prediction: K
# Ground Truth: A
# --------------------------------------------------
# Sample 518:
# Problem: Find the area of the parallelogram. Round to the nearest tenth if necessary.
# Prediction: 积
# Ground Truth: B
# --------------------------------------------------
# Sample 519:
# Problem: Find $JL$.
# Prediction: K
# Ground Truth: D
# --------------------------------------------------
# Sample 520:
# Problem: Find x.
# Prediction: x
# Ground Truth: D
# --------------------------------------------------
# Sample 521:
# Problem: The segment is tangent to the circle. Find the value of $x$.
# Prediction: X
# Ground Truth: B
# --------------------------------------------------
# Sample 522:
# Problem: Find the perimeter of  $\triangle D E F,$ if $\triangle D E F \sim \triangle C B F,$ perimeter of $\triangle C B F=27, D F=6,$ and $F C=8$
# Prediction: C
# Ground Truth: A
# --------------------------------------------------
# Sample 523:
# Problem: Find the perimeter of the parallelogram. Round to the nearest tenth if necessary.
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 524:
# Problem: Find the area of the figure. Round to the nearest tenth if necessary.
# Prediction: figure
# Ground Truth: C
# --------------------------------------------------
# Sample 525:
# Problem: Equilateral pentagon $P Q R S T$ is inscribed in $\odot U$. Find $m \widehat{Q R}$
# Prediction: U
# Ground Truth: B
# --------------------------------------------------
# Sample 526:
# Problem: In $\odot M$, $FL=24,HJ=48$, and $m \widehat {HP}=65$. Find $NJ$.
# Prediction: M
# Ground Truth: A
# --------------------------------------------------
# Sample 527:
# Problem: If $ZP = 4x - 9$ and $PY = 2x + 5$, find $ZX$.
# Prediction: P
# Ground Truth: D
# --------------------------------------------------
# Sample 528:
# Problem: Find $A E$ if $A B=12, A C=16,$ and $E D=5$
# Prediction: A
# Ground Truth: B
# --------------------------------------------------
# Sample 529:
# Problem: Find $m \angle 1$.
# Prediction: Q
# Ground Truth: C
# --------------------------------------------------
# Sample 530:
# Problem: For trapezoid QRTU, V and S are midpoints of the legs. If QR = 4 and UT = 16, find VS.
# Prediction: V
# Ground Truth: C
# --------------------------------------------------
# Sample 531:
# Problem: The two polygons are similar. Find UT.
# Prediction: U
# Ground Truth: C
# --------------------------------------------------
# Sample 532:
# Problem: Find $BD$ if $\overline{B F}$ bisects $\angle A B C$ and $\overline{A C} \| \overline{E D}, B A=6, B C=7.5$, $A C=9,$ and $D E=9$
# Prediction: C
# Ground Truth: B
# --------------------------------------------------
# Sample 533:
# Problem: Find the scale factor from $Q$ to $Q'$.
# Prediction: Q
# Ground Truth: B
# --------------------------------------------------
# Sample 534:
# Problem: Find x to the nearest tenth. Assume that segments that appear to be tangent are tangent.
# Prediction: segments
# Ground Truth: D
# --------------------------------------------------
# Sample 535:
# Problem: Find the area of the rhombus.
# Prediction: rh
# Ground Truth: C
# --------------------------------------------------
# Sample 536:
# Problem: Express the ratio of $\cos B$ as a decimal to the nearest hundredth.
# Prediction: C
# Ground Truth: A
# --------------------------------------------------
# Sample 537:
# Problem: Find y
# Prediction: y
# Ground Truth: A
# --------------------------------------------------
# Sample 538:
# Problem: Find x
# Prediction: X
# Ground Truth: D
# --------------------------------------------------
# Sample 539:
# Problem: Find x.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 540:
# Problem: Quadrilateral $WXYZ$ is a rectangle. Find the measure of $\angle 5$ if $m∠1 = 30$.
# Prediction:
# Ground Truth: B
# --------------------------------------------------
# Sample 541:
# Problem: Find the area of the shaded region. Round to the nearest tenth.
# Prediction: shaded
# Ground Truth: B
# --------------------------------------------------
# Sample 542:
# Problem: $m \widehat{AC}=160$ and $m \angle BEC=38$. What is $m \angle AEB$?
# Prediction: BE
# Ground Truth: A
# --------------------------------------------------
# Sample 543:
# Problem: Find the area of the regular polygon. Round to the nearest tenth.
# Prediction: hex
# Ground Truth: C
# --------------------------------------------------
# Sample 544:
# Problem: Find the area of the parallelogram. Round to the nearest tenth if necessary.
# Prediction: paralle
# Ground Truth: B
# --------------------------------------------------
# Sample 545:
# Problem: Find x.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 546:
# Problem: $\triangle RSV \cong \triangle TVS$. Find $x$.
# Prediction: S
# Ground Truth: C
# --------------------------------------------------
# Sample 547:
# Problem: In $\odot O, \overline{E C}$ and $\overline{A B}$ are diameters, and $\angle B O D \cong \angle D O E \cong \angle E O F \cong \angle F O A$
# Find $m\widehat{A C}$
# Prediction: O
# Ground Truth: B
# --------------------------------------------------
# Sample 548:
# Problem: In $\odot M$, $FL=24,HJ=48$, and $m \widehat {HP}=65$. Find $m \widehat {HJ}$.
# Prediction: M
# Ground Truth: C
# --------------------------------------------------
# Sample 549:
# Problem: Find $AB$.
# Prediction: B
# Ground Truth: A
# --------------------------------------------------
# Sample 550:
# Problem: Trapezoid $GHJK$ has an area of 188.35 square feet. If $HJ$ is 16.5 feet, find $GK$.
# Prediction: 积
# Ground Truth: D
# --------------------------------------------------
# Sample 551:
# Problem: Find x.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 552:
# Problem: Find $m \angle D$.
# Prediction: Circle
# Ground Truth: C
# --------------------------------------------------
# Sample 553:
# Problem: Find $m \angle 1$.
# Prediction: m
# Ground Truth: D
# --------------------------------------------------
# Sample 554:
# Problem: Find the area of the figure to the nearest tenth.
# Prediction: figure
# Ground Truth: B
# --------------------------------------------------
# Sample 555:
# Problem: In the figure, $m ∠9 = 75$. Find the measure of $\angle 6$.
# Prediction: m
# Ground Truth: D
# --------------------------------------------------
# Sample 556:
# Problem: Find $x$.
# Prediction: W
# Ground Truth: C
# --------------------------------------------------
# Sample 557:
# Problem: Find x.
# Prediction: x
# Ground Truth: C
# --------------------------------------------------
# Sample 558:
# Problem: Find the perimeter of the parallelogram.
# Prediction: paralle
# Ground Truth: D
# --------------------------------------------------
# Sample 559:
# Problem: Find $JQ$ if $Q$ is the incenter of $\triangle JLN$.  Rounded to the nearest hundredth.
# Prediction: Q
# Ground Truth: B
# --------------------------------------------------
# Sample 560:
# Problem: The area of trapezoid $JKLM$ is 138 square feet. The area of trapezoid $QRST$ is 5.52 square feet. If trapezoid $J K L M$ $ \sim$ trapezoid $QRST$, find the value of $x$.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 561:
# Problem: Find $BC$.
# Prediction: 角
# Ground Truth: B
# --------------------------------------------------
# Sample 562:
# Problem: $\triangle ABC \sim \triangle FDG$. Find the value of $x$.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 563:
# Problem: Find x. Round the side measure to the nearest tenth.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 564:
# Problem: In the figure, $m∠1 = 123$. Find the measure of $\angle 14$.
# Prediction: m
# Ground Truth: B
# --------------------------------------------------
# Sample 565:
# Problem: Find the area of the figure in feet. Round to the nearest tenth, if necessary.
# Prediction: figure
# Ground Truth: A
# --------------------------------------------------
# Sample 566:
# Problem: If $\frac{I J}{X J}=\frac{HJ}{YJ}, m \angle W X J=130$
# and $m \angle WZG=20,$ find $m \angle YIZ$
# Prediction:
# Ground Truth: B
# --------------------------------------------------
# Sample 567:
# Problem: The diameter of $\odot S$ is $30$ units, the diameter of $\odot R$ is $20$ units, and $DS=9$ units. Find $RC$.
# Prediction: C
# Ground Truth: A
# --------------------------------------------------
# Sample 568:
# Problem: Find y.
# Prediction: y
# Ground Truth: D
# --------------------------------------------------
# Sample 569:
# Problem: Find PQ
# Prediction: PQ
# Ground Truth: C
# --------------------------------------------------
# Sample 570:
# Problem: For the pair of similar figures, use the given areas to find $x$.
# Prediction: A
# Ground Truth: B
# --------------------------------------------------
# Sample 571:
# Problem: $m∠9 = 2x - 4$, $m∠10 = 2x + 4$. Find the measure of $∠10$.
# Prediction: ten
# Ground Truth: B
# --------------------------------------------------
# Sample 572:
# Problem: In the figure, $m∠3 = 43$. Find the measure of $\angle 11$.
# Prediction:
# Ground Truth: A
# --------------------------------------------------
# Sample 573:
# Problem: In rhombus LMPQ, $m \angle Q L M=2 x^{2}-10$, $m \angle Q P M=8 x$,  and $M P=10$ .
# Find the perimeter of $LMPQ$
# Prediction: Q
# Ground Truth: B
# --------------------------------------------------
# Sample 574:
# Problem: Find the value of $x$ in each diagram
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 575:
# Problem: If $m \widehat{F E}=118, m \widehat{A B}=108$, $m \angle E G B=52,$ and $m \angle E F B=30$, find $m \widehat{C F}$
# Prediction: m
# Ground Truth: B
# --------------------------------------------------
# Sample 576:
# Problem: Find $x$.
# Prediction: M
# Ground Truth: C
# --------------------------------------------------
# Sample 577:
# Problem: Use rectangle LMNP, parallelogram LKMJ to solve the problem.
# If $L N=10, L J=2 x+1,$ and $P J=3 x-1,$ find $x$
# Prediction: L
# Ground Truth: A
# --------------------------------------------------
# Sample 578:
# Problem: The perimeter of this polygon is 60 centimeters. Find the length of each side of the polygon.
#
# Prediction: perimeter
# Ground Truth: A
# --------------------------------------------------
# Sample 579:
# Problem: $\triangle RST \cong \triangle ABC$. Find $x$.
# Prediction: x
# Ground Truth: B
# --------------------------------------------------
# Sample 580:
# Problem: $\triangle WXY \cong \triangle WXZ$. Find $y$.
# Prediction: triangles
# Ground Truth: B
# --------------------------------------------------
# Sample 581:
# Problem: Find $BC$ if $AB=6, AF=8, BC=x, CD=y$, $DE=2y-3$, and $FE=x+\frac{10}{3}$.
# Prediction: C
# Ground Truth: B
# --------------------------------------------------
# Sample 582:
# Problem: In $\odot B$, $CE=13.5$. Find $BD$. Round to the nearest hundredth.
# Prediction: circle
# Ground Truth: B
# --------------------------------------------------
# Sample 583:
# Problem: Find the area of the rhombus.
# Prediction: Rh
# Ground Truth: B
# --------------------------------------------------
# Sample 584:
# Problem: Find the area of the figure. Round to the nearest tenth.
# Prediction: figure
# Ground Truth: D
# --------------------------------------------------
# Sample 585:
# Problem: Find the area of the trapezoid.
# Prediction: 积
# Ground Truth: C
# --------------------------------------------------
# Sample 586:
# Problem: Quadrilateral EFGH is a rectangle. If FK = 32 feet, find EG.
# Prediction: K
# Ground Truth: D
# --------------------------------------------------
# Sample 587:
# Problem: Find the measure of $\angle 2$.
# Prediction: 叉
# Ground Truth: D
# --------------------------------------------------
# Sample 588:
# Problem: Find the length of $AC$ in the isosceles triangle ABC.
# Prediction: C
# Ground Truth: B
# --------------------------------------------------
# Sample 589:
# Problem: $\overrightarrow{BA}$ and $\overrightarrow{BC}$ are opposite rays and $\overrightarrow{BD}$ bisects $\angle ABF$. If $m \angle FBC=2x+25$ and $m \angle ABF=10x-1$, find $m \angle DBF$.
# Prediction: F
# Ground Truth: D
# --------------------------------------------------
# Sample 590:
# Problem: Find the length of $\widehat {ZY}$. Round to the nearest hundredth.
# Prediction: X
# Ground Truth: C
# --------------------------------------------------
# Sample 591:
# Problem: Find $cos C$
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 592:
# Problem: $\overline{A C}$ is a diagonal of rhombus $A B C D$ If $m \angle C D E$ is $116,$ what is $m \angle A C D ?$
# Prediction: rh
# Ground Truth: A
# --------------------------------------------------
# Sample 593:
# Problem: Find the perimeter of $\triangle R U W$ if $\triangle R U W \sim \triangle S T V$, $S T=24, V S=12, V T=18$ and $U W=21$
# Prediction: V
# Ground Truth: A
# --------------------------------------------------
# Sample 594:
# Problem: For trapezoid $ABCD$, $S$ and $T$ are midpoints of the legs. If $AB=x+4$, $CD=3x+2$, and $ST=9$, find $AB$.
# Prediction: B
# Ground Truth: C
# --------------------------------------------------
# Sample 595:
# Problem: Find the length of $\widehat {JK}$. Round to the nearest hundredth.
# Prediction: C
# Ground Truth: C
# --------------------------------------------------
# Sample 596:
# Problem: In $\odot P$, $JK=10$ and $\widehat {JKL}=134$. Find $m \widehat{JL}$.
# Prediction: Q
# Ground Truth: B
# --------------------------------------------------
# Sample 597:
# Problem: The segment is tangent to the circle. Find $x$.
# Prediction: x
# Ground Truth: A
# --------------------------------------------------
# Sample 598:
# Problem: Find $\angle 5$
# Prediction:
# Ground Truth: A
# --------------------------------------------------
# Sample 599:
# Problem: If $\frac{I J}{X J}=\frac{HJ}{YJ}, m \angle W X J=130$
# and $m \angle WZG=20,$ find $m \angle J$
# Prediction:
# Ground Truth: C
# --------------------------------------------------
# Sample 600:
# Problem: Find DE
# Prediction: F
# Ground Truth: D
# --------------------------------------------------
# Accuricy: 0.016638935108153077
